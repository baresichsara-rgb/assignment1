# %% [markdown]
# <a href="https://colab.research.google.com/github/baresichsara-rgb/assignment1/blob/main/Sara_Baresich_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CISC 121 – Assignment-1
#
# ## 🔗 Problem
# Fizz Buzz – https://leetcode.com/problems/fizz-buzz/
#
# Palindrome Number – https://leetcode.com/problems/palindrome-number/
#
# Reverse Integer – https://leetcode.com/problems/reverse-integer/
#
# Two Sum – https://leetcode.com/problems/two-sum/
#
# Valid Palindrome – https://leetcode.com/problems/valid-palindrome/

# %% [markdown]
# #  Problem 1

# %% [markdown]
# ## 1. Understanding & Breakdown

# %% [markdown]
# Input: an integer inputted by the user, programmed as the variable “n”.
# Output: the program must return a 1-indexed string array. Therefore, the list of strings must begin at 1, and until the integer “n”.
#
# Conditions:
# If the integer input is divisible by 3 and 5, the program must return “FizzBuzz”.
# If the integer is divisible only by 3, the program must return “Fizz”.
# If the integer is divisible by 5, the output is “Buzz”.
# Where the number is not divisible in the list of strings, by any of the above conditions, the output is “i” or in other words, the string itself.
#
# Constraints: the constraints listed here are: 1 <= n <= 10^4
# This implies that the “n” integer must always be a minimum of one, and it cannot be more than 10 000.
#
# 	Steps to Solve the Fizz Buzz Problem:
# 1. Insert the string array to hold the list. “n” is now inputted as an integer.
# 2. Create a for loop, in which the variable “i” will be declared and inputted as 1, so that the loop will account for the numbers beginning from 1, up until “n” is when the for loop will stop.
# 2. Inside of the loop are “if” statements… First, it is calculated if “i” (“i” and not n, since “i” is every passing number being checked up until “n”) can be divisible by 3 and 5. If this statement is fulfilled, “FizzBuzz” will be added for place of the integer.
# 3. Then, there are “else if” statements. If “i” is divisible by 3, then “Fizz” is added in place of the integer. The next “else” repeats similarly, if “i” is divisible by 5, rather, the string “Buzz” will be added instead
# 4. Then, the last “else” adds the remaining numbers themselves as a string… If they are not divisible by 3 or 5, the actual numbers are added.
# 5. Lastly, the for loop is closed, and the list of string arrays is returned as a result.

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# I used a couple solutions as slight guidance in my coding, the first as reference to how my “for” loop should be displayed.
# https://leetcode.com/problems/fizz-buzz/solutions/7202791/beginner-friendly-solution
#
# I also used a second solution, shown below:
#
# https://leetcode.com/problems/fizz-buzz/solutions/6646296/conquer-fizzbuzz-with-the-cleanest-one-liner-logic-ever
# I learned to refine my work. For example, I learned that rather than having to write:
# if (i % 3 == 0 && i % 5 == 0) {
# I could actually just write:
# 	if (i % 15 == 0) {
# So that this line could be a bit shorter, thus cleaning up unnecessary writing.

# %%
# Draft code
class Solution {
public:
    vector<string> fizzBuzz(int n) {
        vector<string> list;

        for (int i = 1; i <= n; i++){
            if (i % 3 == 0 && i % 5 == 0) {
                list.add("FizzBuzz");
            } else if (i % 3 == 0){
                list.add("Fizz");
            } else if (i % 5 == 0){
                list.add("Buzz");
            } else {
                list.add(to_string(i));
            }
        }
        return list;

    }
};

# %% [markdown]
# ## 3. Final Correct Code
#
# I found that my code was not running and I began to review many solutions. I also Googled and realized that the list.add command was for Java coding, and thus, would not working in the Colab Notebook, as the coding there is C++. I kept having errors that kept identifying the list.add. So, although many of the solutions in the LeetCode used the list.add, they were actuall for Java solutions. I found another solution that used a list.push_back command instead. Once I tried this in my else if statements my code was immediately working.
# https://leetcode.com/problems/fizz-buzz/solutions/7187229/optimal-solution

# %%
# Final working solution
# [Disclaimer: I used an additional solution to review and understand why my code was not running.]
class Solution {
public:
    vector<string> fizzBuzz(int n) {
        vector<string> list;

        for (int i = 1; i <= n; i++){
            if (i % 15 == 0) {
                list.push_back("FizzBuzz");
            } else if (i % 3 == 0){
                list.push_back("Fizz");
            } else if (i % 5 == 0){
                list.push_back("Buzz");
            } else {
                list.push_back(to_string(i));
            }
        }
        return list;

    }
};

# %% [markdown]
# Screenshots of working output:
#
# ![Image 2025-09-20 at 8.35 PM.jpeg](data:image/jpeg;base64,...)
#
# ![Image 2025-09-20 at 8.35 PM (1).jpeg](data:image/jpeg;base64,...)
#
#
#
# ![Image 2025-09-20 at 8.35 PM (2).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 4. Review & Fixes

# %%
# Fix 1: Simplifying the original if statement.

# Draft version (manual and longer logic).
if (i % 3 == 0 && i % 5 == 0) {
                list.add("FizzBuzz");

# Fixed version (more logical, easier to look at, removing excess coding).
 if (i % 15 == 0) {
                list.push_back("FizzBuzz");

# %%
# Fix 2: Adjusted the list.add to list.push_back command properly make the words add to the list.

# Draft version: my code was not working, and kept returning error to me (list.add is programmed for Java).
 if (i % 3 == 0 && i % 5 == 0) {
                list.add("FizzBuzz");
            } else if (i % 3 == 0){
                list.add("Fizz");
            } else if (i % 5 == 0){
                list.add("Buzz");
            } else {
                list.add(to_string(i));

# Fixed version: the code now is properly functional and adhering to the Colab program.
 if (i % 15 == 0) {
                list.push_back("FizzBuzz");
            } else if (i % 3 == 0){
                list.push_back("Fizz");
            } else if (i % 5 == 0){
                list.push_back("Buzz");
            } else {
                list.push_back(to_string(i));

# %% [markdown]
# ## 5. Reflection on Your Contribution
# 1. I didn't use ChatGPT for this problem as I have solved ones similar to this before in other programs, but I did look at multiple other codes in the solutions on LeetCode. I used these to identify how I was going to attempt to write my code and different kinds of formatting. This one seemed one of the most logical to me, for example, I saw versions in which the solutions tried to veer away from using the % sign whilst dividing.
#
# 2. I did have some problems at the beginning where I was slightly confused on how to list the array list, I was trying to code more of a Java string, for example, writing "new" before calling on the array. However before running it, once I reviewed other solutions to view some of their cleaner codes, did I realize that I was writing more than I had to than needed for the Colab, and that it wouldn't have worked anyhow.
#
# 3. I was able to construct the for loop almost entirely by myself, besides for the fact that my code wouldn't run since I had some Java coding in there as well (the list.add command). I reviewed solutions to fix this so my code would run, as well as updating my code to shorten the first else if statement, so that it would write i % 15 rather than the unnecessary (writing both i % 3 && i % 5).

# %% [markdown]
# # Problem 2

# %% [markdown]
# ## 1. Understanding & Breakdown

# %% [markdown]
# Input: an integer presented as the variable "x". Output: the program reads "true" if the integer "x" (once reversed) is a palindrome. If the integer is not a palindrome, the integer will output "false".
#
# Conditions: if the value x < 0, or if x ends in a 0, then the program will automatically return "false", as these cases both cannot be a palindrome. If the value, once reversed, is equal to x (its initial value), then the program will return "true" (it is a palindrome). However, if the reversed value of x does not equal to x, the program will return "false" as this is also not a palindrome.
#
# Constraints: -2^31 <= x <= 2^31 - 1
#
# Steps to Solve the Palindrome Problem:
# 1. Define the palindrome function and use bool as a ways to determine if x is true or false. Define x as a variable.
# 2. Write an if statement: if x < 0 or if x ends in the digit 0 (as long as x is not actually 0), then return the integer as false.
# 3. Create a reverse variable = 0.
# 4. Create a while loop, in which x's values are reversed (only half of the palindrome's values are reversed, as to avoid error) and are set to the variable. This is done by calculating the remainder of x (using mod) by dividing by 10. In this way, the last digit is able to be found, reversed, and set as the reverse variable, one digit at a time.
# 5. Return function wherein if x = rev (the reverse variable), or if x = rev after being divided by 10 (in case it is an odd digit number), then it is a palindrome, therefore is returned as true. If x is not equal to rev, then the function is returned as false.

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# I used this solution on LeetCode as guidance on how to approach the palindrome problem.
# https://leetcode.com/problems/palindrome-number/solutions/6826784/beats-100-step-by-step-visualization-java-c-python-beginner-friendly
# I learned how the while loops work in greater detail, such that the rev begins at 0 and continues to work, and numbers are added, until it fulfills its condition.

# %%
# Draft Code
class Solution {
public:
    bool isPalindrome(int x) {

        if (x < 0 && x % 10 == 0) return false;
        int rev = 0;
        while (x>0){
            rev = rev * 10 + x % 10;
            x/=10;
        }
        return (x==rev || x == rev/10);


    }
};

# %% [markdown]
# ## 3. Final Correct Code

# %%
# Final Working Solution
# [AI Disclaimer: utilized ChatGPT with prompt "Why isn't my code working correctly"]
# I couldn't figure out why my code wasn't working... I had forgotten to write || for the if statement
class Solution {
public:
    bool isPalindrome(int x) {

        if (x < 0 || (x % 10 == 0 && x != 0)) return false;
        int rev = 0;

        while (x > rev) {
            rev = rev * 10 + x % 10;
            x /= 10;
        }
        return (x==rev || x == rev/10);




    }
};

# %% [markdown]
# Screenshots of working output:
# ![Image 2025-09-20 at 11.50 PM (1).jpeg](data:image/jpeg;base64,...)
#
# ![Image 2025-09-20 at 11.50 PM.jpeg](data:image/jpeg;base64,...)
#
# ![Image 2025-09-20 at 11.49 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 4. Review & Fixes

# %%
# Fix 1: Correcting my if statement conditions.

# Draft version (incorrect condition in if statement)
if (x < 0 && x % 10 == 0) return false;

# Fixed version (more logical, correct condition)
 if (x < 0 || (x % 10 == 0 && x != 0)) return false;

# %%
# Fix 2: Ensuring that error is eliminated, as well as ensuring efficiency by reversing only the necessary numbers.

# Draft version (looping until 0, which may cause errors)
while (x>0){

# Fixed version (looping until only the necessary half-way point, eliminating error)
while (x > rev) {

# %% [markdown]
# ## 5. Reflection on Your Contribution
# 1. I utilized ChatGPT (Level 4) in order to help me identify errors in my code, which overall improved some efficiency. For example, ChatGPT identified two errors to me, such that I needed to use the OR operator (||) rather than simply writing the AND operator (&&) in my if statement. This was a necessary step as the AND operator continued to cause errors in my coding, which I had trouble identifying myself. Fixing this part of the code ensured that there were two conditions that could be fufilled.
#
# 2. I also used ChatGPT to help identify another plausible error, such that if it had not been fixed, there may have been complications with my program if the integers inputted had been high numbers. Meaning, for my while statement, my loop first wouldn't complete until all the numbers had been reversed, in order to solve the Palindrome problem. However, after the fix, the code then would loop only until the reverse number met the halfway point of x. This eliminated unnecessary steps, since the loop only needs to be completed halfway as it is a Palindrome number.
#
# 3. I reviewed a popular solution in LeetCode to help me understand how I was to approach the code, which helped me to write the if statement (although it was incorrect). I contributed my own logic mainly for the while loop (although there were also things to fix there, such as the while loop statement), but overall I was able to complete that, as well as the return function with my own knowledge.

# %% [markdown]
# # Problem 3

# %% [markdown]
# ## 1. Understanding & Breakdown

# %% [markdown]
# Input: given a value, represented as x, which remains inside the 32-bit integer. This refers to a certain large number that cannot go outside this range. Output: the value of x will be returned with its digits reversed.
#
# Conditions: if the number goes outside the 32-bit integer, rather than returning the reversed integer, the program will return 0.
#
# Constraints: -2^31 <= x <= 2^31 - 1
#
# Steps to Solve the Reverse Integer Problem:
# 1. Define x (the number being reversed) as well as the reversed variable (rev) as integers. "rev" is defined as 0 since it has not been added to yet.
# 2. Create a while loop, that will run until all the digits in x have been reviewed and translated to the rev integer. The int digit in this loop will calculate the last digit of x (by determining the remainder using the mod function).
# 3. Create an if loop in which checks that the 32-bit integer is not an overflow.
# 4. Add the new digit of x to the reversed number (the remainder), and remove this digit from x.
# 5. Once x becomes 0, the while loop will closed, and the reverse number, rev, will be returned.

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# In the LeetCode solutions, I reviewed a couple of the top solutions as guidance while writing my code. However, I tried to solve it somewhat similarly to the Palindrome problem. Although they are different I was able to use a  similar line, such as when the reversed number (rev) is being added to and replacing x.

# %%
# Draft
class Solution {
public:
    int reverse(int x) {
        int rev = 0;

        while (x != 0) {
            int digit = x % 10;

            if ((rev > INT_MAX / 10) || (rev < INT_MIN / 10)) {
                return 0;
            }

            rev = rev * 10 + digit;
            x = x / 10;
        }
        return rev;
    }
};

# %% [markdown]
# ## 3. Final Correct Code

# %%
# Final Working Solution
# [AI Disclaimer: I used ChatGPT to review my code (although my prior code was working), which corrected the overflow]
# [Used the ChatGPT with the prompt: "Are there plausible errors in this reverse integer problem?"]

class Solution {
public:
    int reverse(int x) {
        int rev = 0;

        while (x != 0) {
            int digit = x % 10;
            x /= 10;

            if ((rev > INT_MAX / 10) ||
               (rev == INT_MAX / 10 && digit > 7)) {

            return 0;
            }

            if ((rev < INT_MIN / 10) ||
               (rev == INT_MIN / 10 && digit < -8)) {

               return 0;
               }

            rev = rev * 10 + digit;
        }
        return rev;
    }
};

# %% [markdown]
# Screenshots of working code:
# ![Image 2025-09-21 at 11.38 PM.jpeg](data:image/jpeg;base64,...)
# ![Image 2025-09-21 at 11.39 PM.jpeg](data:image/jpeg;base64,...)
# ![Image 2025-09-21 at 11.39 PM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 4. Review & Fixes

# %%
# Fix 1: Correcting my overflow lines so that they work properly; ie. within the 32-bit integer

# Draft version (won't catch certain edge cases where overflow may occur)
  if ((rev > INT_MAX / 10) || (rev < INT_MIN / 10)) {

# Fixed version (now prevents the overflow)
 if ((rev > INT_MAX / 10) ||
     (rev == INT_MAX / 10 && digit > 7)) {

      return 0;
      }

 if ((rev < INT_MIN / 10) ||
     (rev == INT_MIN / 10 && digit < -8)) {

      return 0;

# %%
# Fix 2: adding brackets so that the program can execute

# Draft version (wasn't executing properly)
if ((rev > INT_MAX / 10 || # notice here I forgot to add brackets
     (rev == INT_MAX / 10 && digit > 7)) {

      return 0;
      }

 if ((rev < INT_MIN / 10 ||
     (rev == INT_MIN / 10 && digit < -8)) {

 # Fixed version (now the program can execute)
  if ((rev > INT_MAX / 10) ||
     (rev == INT_MAX / 10 && digit > 7)) {

      return 0;
      }

 if ((rev < INT_MIN / 10) ||
     (rev == INT_MIN / 10 && digit < -8)) {

      return 0;

# %% [markdown]
# ## 5. Reflection on Your Contribution

# %% [markdown]
# 1. I utilized ChatGPT (Level 4) simply to review my coding before I finished, however, it caught the mistake that my code was not precisely preventing overflow, such as edge cases where the overflow could occur on the next digit. After this I revised my code greatly, although it included more lines, however in this way it was able to more accurately prevent any chance of overflow.
#
# 2. My own logic came in where I was confused for quite some time on why my program was not working. However, after looking for quite a while, I eventually realized I hadn't had the appropriate number of brackets for my if statements. After that, the code ran smoothly.
#
# 3. I used some LeetCode solutions to help me in the beginning writing process of this code, however I came to the realization that it wasn't very correct and would not prevent much overflow or errors.

# %% [markdown]
# # Problem 4

# %% [markdown]
# ## Understanding & Breakdown

# %% [markdown]
# Input: an arrays of integers (defined as num) as well as the target integer, which is the num of two integers in the array. Output: displays two indices of the two numbers that add up to target.
#
# Constraints:
# 2 <= nums.length <= 10^4
# -10^9 <= nums [i] <= 10^9
# -10^9 <= target <= 10^9
#
# Steps to Solve the Two Sum Problem:
#
# 1. Declare a hash table, begin to build the hash table by using a for loop.
# 2. The for loop will loop through the array to identify each of them numbers and add them to the hash table.
# 3. Create amother for loop that will identify what the numbers are in the array that add up to the target, and the output for those numbers. This is completed by subracting each of the numbers, one at a time, from the target, which equals the other number (the complement).
# 4. If the complement is existing in the hash table, a count will be added for that particular number for the index. If the complement in not existing, the return is empty, and the code continues to loop until it finds a complement.
# 5. Return the correct indices.

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# For guidance on the Two Sum problem, I reviewed one of the top solutions on LeetCode, and also the website GeeksforGeeks in order to understand how to implement hash tables:
# https://www.geeksforgeeks.org/dsa/implementation-of-hash-table-in-c-using-separate-chaining/
# I learned how hash tables store the values of indexes.

# %%
# Draft Code
class Solution {
public:
    vector<int> twoSum(vector<int>& nums, int target) {
        unordered_map<int, int> numMap;
        int size = nums.size();

        for (int i = 0; i < size; i++) {
            numMap [nums[i]] = i;
        }

        for (int i = 0; i < size; i++) {
            int complement = target - nums[i];
            if (numMap.count(complement) && numMap[complement] != i) {
                return {i, numMap[complement]};
            }
        }

        return {};


    }
};

# %% [markdown]
# ## 3. Final Correct Code

# %%
# Final Working Solution
# [AI Disclaimer. I used ChatGPT to define the errors: "How am I able to improve this code? Are there errors?"]
class Solution {
public:
    vector<int> twoSum(vector<int>& nums, int target) {
        unordered_map<int, int> numMap;

        for (int i = 0; i < nums.size(); ++i){
            int complement = target - nums[i];

            if (numMap.find(complement) != numMap.end()){
                return {numMap[complement], i};
            }

            numMap[nums[i]] = i;
        }
        return {};


    }
};

# %% [markdown]
# Screenshots of working code:
# ![Image 2025-09-24 at 5.39 PM.jpeg](data:image/jpeg;base64,...)
#
# ![Image 2025-09-24 at 5.23 PM.jpeg](data:image/jpeg;base64,...)
#
# ![Image 2025-09-24 at 5.23 PM (2).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 4. Review & Fixes

# %%
# Fix 1: Modifying the loops so that there is a single loop rather than two loops in the code.

# Draft Version (one to build the hash table, the other to search: less efficient).

        for (int i = 0; i < size; i++) {
            numMap [nums[i]] = i;
        }

        for (int i = 0; i < size; i++) {
            int complement = target - nums[i];
            if (numMap.count(complement) && numMap[complement] != i) {
                return {i, numMap[complement]};
            }
        }

# Fixed Version (builds the hash table and searches in the same loop now, more clean and efficient).

        for (int i = 0; i < nums.size(); ++i){
            int complement = target - nums[i];

            if (numMap.find(complement) != numMap.end()){
                return {numMap[complement], i};
            }

            numMap[nums[i]] = i;
        }

# %%
# Fix 2: Modifying the if command so that the complement check is more accurate.

# Draft Version (the if complement is in a separate for loop: it may reject valid duplicate numbers).
 if (numMap.count(complement) && numMap[complement] != i) {
                return {i, numMap[complement]};

# Fixed Version (stores previous values before it handles complements, accurately handles duplicates).
  if (numMap.find(complement) != numMap.end()){
                return {numMap[complement], i};

# %% [markdown]
# ## 5. Reflection on Your Contribution

# %% [markdown]
# 1. I mainly wrote the code for the Two Sum Problem myself. While I reviewed some solutions on LeetCode in the beginning processes of writing, my code was still functional before I used any other AI.
# 2. After writing my code I used ChatGPT (Level 4) to help read through my code in case there were any possible errors or anything I could improve on (there were).
# 3. I used this AI to help shorten the loops so that there was a single loop instead, which helped to eliminate plausible error, especially surrounding arrays where duplicate numbers may exist.

# %% [markdown]
# # Problem 5

# %% [markdown]
# ## Understanding & Breakdown

# %% [markdown]
# Input: alphanumeric characters (letters and numbers). Output: true or false. True if the sequence of alphanumeric characters reads the same forwards and backwards (a reflection), and false if the sequence does not read the same forwards and backwards.
#
# Constraints:
# 1 <= s.length <= 2 * 10^5.
# s must consist of only printable ASCII characters.
#
# Steps to Solving the Valid Palindrome Problem:
# 1. Create variables for checking the characters in the problem.
# 2. Create the while loop in which will compare characters. It runs as long as left < right.
# 3. Create while loops that skip unnecessary characters (spaces and punctuation so that characters are simply bound together), and verify alphanumerical characters.
# 4. Ignore case and compare characters.
# 5. Return true if the characters are a palindrome; return false if the sequence is not a palindrome.

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# In this code I also used here the top solutions on LeetCode to build my program. I wanted to attempt to solve this similarly to the other Palindrome problem (problem 2). However I learned that this one works quite differently with letters. I also learned the function islanum, which is specific to checking alphanumeric numbers.

# %%
# Draft Code
class Solution {
public:
    bool isPalindrome(string s) {
        int left = 0;
        int right = s.length();

        while (left <= right) {
            while (left < right && !isalnum(s[left])) {
                left++;

            }
            while (left < right && !isalnum(s[right])){
                right--;
            }

            if(s[left] != s[right]) {
                return false;
            }
            left++;
            right--;
        }

        return true;

    }
};

# %% [markdown]
# ## 3. Final Correct Code

# %%
# Final Working Solution
# [AI Disclaimer: used ChatGPT with prompt: "Why is my code not running correctly?"]
class Solution {
public:
    bool isPalindrome(string s) {
        int left = 0;
        int right = s.size() -1;

        while (left < right) {
            while (left < right && !isalnum(s[left])) {
                left++;

            }
            while (left < right && !isalnum(s[right])){
                right--;
            }

            if(tolower(s[left]) != tolower(s[right])) {
                return false;
            }
            left++;
            right--;
        }

        return true;

    }
};

# %% [markdown]
# ## 4. Review & Fixes

# %%
# Fix 1: Fixing the index since the string must begin at 0.

# Draft Version (it is beginning at 1 rather than 0).
 int right = s.length();

 # Fixed Version (beginning the index properly at 0).
 int right = s.size() -1;

# %%
# Fix 2: ensuring the alphanumericals are being converted to lowercase to compare more accurately.

# Draft Version (is not converting the characters to lowercase here).
if(s[left] != s[right]) {

# Fixed Version (is now converting the characters so the code will turn out more correctly).
if(tolower(s[left]) != tolower(s[right])) {

# %% [markdown]
# ## 5. Reflection on Your Contribution

# %% [markdown]
# 1. I used ChatGPT (Level 4) to help identify some of my errors as to why my code wasn't working. This included not properly indexing my string variable (the first index of the string was set to 1 rather than 0).
# 2. ChatGPT also helped me to recognize that I needed to implement some sort of case translater, so that any upper case characters would be converted in lower case.
# 3. However, I corrected most of these by myself (after the AI was able to help me recognize the problem), as well as constructed the code by myself, although my draft was incorrect at first.

# %% [markdown]
# # Information

# %% [markdown]
# 1. Your Name: Sara Baresich
# 2. Section: CISC 121 - 001
# 3. ID: 20539156
# 4. https://github.com/baresichsara-rgb/assignment_1.git
# 5. https://docs.google.com/document/d/1RkbwaNB6yMaYPBFsYxaUXYTL0I13VdAiJTJgTrp004s/edit?usp=sharing
